# %% [markdown]
# # Question 1

# %%
import pandas as pd

# %%
df1 = pd.read_csv('timeSpent.csv')
df2 = pd.read_csv('cost.csv')

# %%
df1
# Out:
#       users   timeSpent
# 0  Sushmita   31.266056
# 1      Adam   17.900529
# 2     Benny  265.236086
# 3    Anurag   42.470696

# %%
df2
# Out:
#       users  cost
# 0      Adam  20.0
# 1    Anurag   NaN
# 2     Benny  15.0
# 3  Sushmita   2.0
# 4   Apoorva   7.0

# %%
df2['cost'].fillna(df2['cost'].mean(), inplace = True)
df2
# Out:
#       users  cost
# 0      Adam  20.0
# 1    Anurag  11.0
# 2     Benny  15.0
# 3  Sushmita   2.0
# 4   Apoorva   7.0

# %%
series1 = df1.squeeze()
series1
# Out:
#       users   timeSpent
# 0  Sushmita   31.266056
# 1      Adam   17.900529
# 2     Benny  265.236086
# 3    Anurag   42.470696

# %%
series2 = df2.squeeze()
series2
# Out:
#       users  cost
# 0      Adam  20.0
# 1    Anurag  11.0
# 2     Benny  15.0
# 3  Sushmita   2.0
# 4   Apoorva   7.0

# %%
result = pd.merge(series1,series2)
result
# Out:
#       users   timeSpent  cost
# 0  Sushmita   31.266056   2.0
# 1      Adam   17.900529  20.0
# 2     Benny  265.236086  15.0
# 3    Anurag   42.470696  11.0

# %%
user_behaviour =  pd.merge(df1,df2)
user_behaviour
# Out:
#       users   timeSpent  cost
# 0  Sushmita   31.266056   2.0
# 1      Adam   17.900529  20.0
# 2     Benny  265.236086  15.0
# 3    Anurag   42.470696  11.0

# %%
user_behaviour
# Out:
#       users   timeSpent  cost
# 0  Sushmita   31.266056   2.0
# 1      Adam   17.900529  20.0
# 2     Benny  265.236086  15.0
# 3    Anurag   42.470696  11.0

# %% [markdown]
# # Question 2

# %%
user_info = pd.read_json('user_info.json')
user_info
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
# 5  5c0a28d749ce43912931715e      5  1d4dcbcd-c5b7-45a8-9650-82d7f98305c6
#
#    isActive    balance                    picture  age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
# 5      True  $2,441.66  http://placehold.it/32x32   23    green
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
average_age  = user_info['age'].mean()
print('The average age of the users is :',average_age)
# Out:
# The average age of the users is : 27.833333333333332

# %%
favourite = user_info['favoriteFruit'].mode()[0]
favourite
# Out:
# 'apple'

# %%
fgm = user_info['gender'].value_counts()
fgm
# Out:
# gender
# female    3
# male      3
# Name: count, dtype: int64

# %%
user_info['gender'].value_counts()
# Out:
# gender
# female    3
# male      3
# Name: count, dtype: int64

# %%
active_users = user_info['isActive'].value_counts().loc[True]
active_users
# Out:
# 3
